# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from utils_prodiac.mongo import Mongo
import matplotlib.pyplot as plt
import datetime

from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
pd.plotting.register_matplotlib_converters()
pd.set_option('large_repr', 'info')
pd.set_option('precision', 4)
pd.set_option('display.max_rows', 100)
#pd.get_option('max_rows')

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
mongo = Mongo()

# %%
id_measurement = 1
df_original = mongo.mongo_to_df("twitter",{"id_measurement":id_measurement})
#df_original.sort_values(by=['date'], inplace=True, ascending=False)

# %%
df_original
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19612 entries, 0 to 19611
# Data columns (total 42 columns):
# _id                         19612 non-null object
# id_tweet                    19612 non-null int64
# text_tweet                  19612 non-null object
# date                        19612 non-null datetime64[ns]
# is_retweet                  19612 non-null bool
# retweet_status_id           17410 non-null float64
# retweet_text                17410 non-null object
# retweet_user_id             17410 non-null float64
# retweet_user_screen_name    17410 non-null object
# geo                         0 non-null object
# coordinates                 0 non-null object
# retweet_count               19612 non-null int64
# favorite_count              19612 non-null int64
# reply_count                 19612 non-null int64
# favorited                   19612 non-null bool
# retweeted                   19612 non-null bool
# filter_level                19612 non-null object
# ...

# %%
x= df_original['date']
y= df_original["user_followers_count"]
title = "test"

# %%
from bokeh.models import DatetimeTickFormatter
plot = figure(title= title , 
        x_axis_label= 'X-Axis', 
        y_axis_label= 'Y-Axis', 
        plot_width =800,
        plot_height =400,
        x_axis_type="datetime",
        tools="save",
        )
plot.step(x, y, legend= 'f(x)', line_width = 2, )
show(plot)
# Out:
#   <div class="bk-root" id="46973282-9509-436f-8a92-8a5dd31ff26e" data-root-id="2427"></div>

# %%
zoom_out, ybox_select, ybox_zoom, ypan, ywheel_pan, ywheel_zoom, yzoom_in, yzoom_out, zoom_in or zoom_out
